# %%
l=[10,5,20,3,30,7,40,50]
l
# Out:
# [10, 5, 20, 3, 30, 7, 40, 50]

# %%
result=[x for x in l  if x%2==1] # comprehensive for loop
print(result)
# Out:
# [5, 3, 7]

# %%
# Out:
# [10, 20, 30, 40, 50]
