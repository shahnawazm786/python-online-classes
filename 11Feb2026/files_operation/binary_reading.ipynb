# %%
with open('data.txt','r') as f:
    content=f.read()
    print(content)
    f.close()
# Out:
# This is data file

# %%
content=b'Hell!!! world, This is example of binary file'
with open("binary_data.txt","wb+") as w:
    w.write(content)
    w.close()

# %%
with open("binary_data.txt","rb+") as fbr:
    text=fbr.read()
    print(text)
    fbr.close()
# Out:
# b'Hell!!! world, This is example of binary file'
