# %%
fw=open("my_bio_data.txt","w")
fw.write('This is my bio-data')
fw.write('\nI am software engineer')
fw.close()
fw=None
print('Written into file completed....')
# Out:
# Written into file completed....

# %%
fw=open("my_bio_data.txt","w")
fw.write('I am living in india')
fw.write('\nI am good citizen')
fw.close()
fw=None
print('Written into file completed....')
# Out:
# Written into file completed....

# %%
fw=open("my_bio_data.txt","a")
fw.write('\nI open the file in append mode')
fw.write('\nvery good....')
fw.close()
fw=None
print('Written into file completed....')
# Out:
# Written into file completed....

# %%
fw=open("my_bio_data_append.txt","a")
fw.write('\nI open the file in append mode')
fw.write('\nvery good....')
fw.close()
fw=None
print('Written into file completed....')
# Out:
# Written into file completed....

# %%
with open("my_bio_data_append.txt","a") as fw:
    fw.write('\nI open the file in append mode')
    fw.write('\nvery good....')
    fw.close()
    fw=None
print('Written into file completed....')
# Out:
# Written into file completed....
